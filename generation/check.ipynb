# %%
import json 
import os 


def slash():
    print('-' * 30)

data_folder_name = './item_profile'
item_prompts_path = os.path.join(data_folder_name, 'item_prompts.json')


item_prompts = []
with open(item_prompts_path, 'r') as f:
    for line in f.readlines():
        data = json.loads(line)
        item_prompts.append(data)

user_prompts = []
with open('./user_profile/user_prompts.json', 'r') as f:
    for line in f.readlines():
        data = json.loads(line)
        user_prompts.append(data)


print(item_prompts[0]['prompt'])
slash()
print(type(user_prompts[0]['prompt']))
data = json.loads(user_prompts[0]['prompt'])
print(data['PURCHASED BUSINESSES'])
# Out:
# BASIC INFORMATION:
# {'name': 'BK Tacos', 'city': 'Tucson', 'categories': 'Restaurants, Tacos, Mexican, Hot Dogs, Breakfast & Brunch, Steakhouses'}
# USER FEEDBACK:
# ...
